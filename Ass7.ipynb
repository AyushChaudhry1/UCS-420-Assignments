# %% [markdown]
# # Assignment 7
#
# <b>Question Q1</b> You are a data analyst at an e-commerce company. Your task is to analyze sales data,
# clean and process it, perform statistical analysis, and generate visual insights to help the business make informed decisions.
#
# Use your roll number as the random seed to generate unique data for each student.
# Follow the questions step by step, as each part builds upon the previous one.
# Submit the assignment as a Jupyter Notebook (.ipynb) with:
# Well-documented code and clear comments.
# Markdown explanations for each step.
# Screenshots of the plots and outputs.
# Part I: Randomized Sales Data Generaton (NumPy)
#
# Initialize Random Seed
# Generate Sales Data
# Create a NumPy array of random sales data for 12 months (shape = (12, 4)), where each column represents a product category:
# Electronics, Clothing, Home & Kitchen, Sports.
# Sales values should be between 1000 and 5000 units per month.
# The range should be randomized using the seed.
# Convert to DataFrame
# Convert the cleaned NumPy array into a Pandas DataFrame with:
# Columns: Electronics, Clothing, Home & Kitchen, Sports
# Index: Months from Jan to Dec
# Part II: Data Manipulation and Analysis (Pandas)
#
# Display the first 5 rows and summary statistics of the DataFrame.
# Calculate the total sales per category and total sales per month.
# Calculate the average sales growth between consecutive months for each category.
# Add the following columns to the DataFrame:
# Total Sales: Sum of all categories per month.
# Growth Rate: Percentage change in Total Sales from the previous month.
# Apply a randomized discount:
# If your roll number is even, apply a 10% discount to the Electronics category
# If odd, apply a 15% discount to the Clothing category.
# Part III: Visualizations (Matplotlib and Seaborn)
#
# Plot monthly sales trends for each category using line plots.
# Create the following plots:
# Box plots to show the sales distribution for each category.

# %%
import numpy as np
import pandas as pd
r_no = 102317183
np.random.seed(r_no)

sales_data = np.random.randint(1000, 5000, size=(12, 4))

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
columns = ["Electronics", "Clothing", "Home & Kitchen", "Sports"]

sales = pd.DataFrame(sales_data, index=months, columns=columns)

print(sales)
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         1886      4795            2345    4148
# Feb         1487      1912            3200    3029
# Mar         4663      1285            3304    2403
# Apr         4829      1223            1559    4379
# May         2519      2719            3524    2665
# Jun         2659      1918            4749    1054
# Jul         2680      2371            3024    3476
# Aug         1943      1793            3394    1208
# Sep         2267      1590            1485    3764
# Oct         1331      2076            1651    2024
# Nov         2273      2602            1408    3834
# Dec         1203      4891            4836    3742

# %%
print(sales.head())
print()
print(sales.describe())

total_sales_per_category = sales.sum()
print()
print(total_sales_per_category)

total_sales_per_month = sales.sum(axis=1)
print()
print(total_sales_per_month)

average_growth = sales.pct_change().mean()
print()
print(average_growth)

sales["Total Sales"] = total_sales_per_month
sales["Growth Rate"] = sales["Total Sales"].pct_change() * 100

if(r_no%2==0):
  sales["Electronics"] *= 0.9
else:
  sales["Clothing"] *= 0.85
print()
print(sales)
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         1886      4795            2345    4148
# Feb         1487      1912            3200    3029
# Mar         4663      1285            3304    2403
# Apr         4829      1223            1559    4379
# May         2519      2719            3524    2665
#
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   2478.333333  2431.250000     2873.250000  2977.166667
# std    1168.651930  1217.349589     1204.344795  1115.588376
# min    1203.000000  1223.000000     1408.000000  1054.000000
# 25%    1786.250000  1742.250000     1628.000000  2308.250000
# 50%    2270.000000  1997.000000     3112.000000  3252.500000
# 75%    2664.250000  2631.250000     3426.500000  3781.500000
# max    4829.000000  4891.000000     4836.000000  4379.000000
#
# Electronics       29740
# Clothing          29175
# Home & Kitchen    34479
# Sports            35726
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(data=sales[columns], markers=True)
plt.title("Monthly Sales Trends for Each Category")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.legend(columns)
plt.grid(True)
plt.show()
print()
print()
plt.figure(figsize=(10, 6))
sns.boxplot(data=sales[columns])
plt.title("Sales Distribution for Each Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %% [markdown]
# <b>Question 2</b> For the array: array = np.array([[1, -2, 3],[-4, 5, -6]])
# Find element-wise absolute value<br>
# Find the 25th, 50th, and 75th percentile of flatened array, for each column, for each row.<br>
# Mean, Median and Standard Deviation of flatened array, of each column, and each row

# %%
import numpy as np

array = np.array([[1, -2, 3], [-4, 5, -6]])


abs_array = np.abs(array)

flat_percentiles = np.percentile(array, [25, 50, 75])  
col_percentiles = np.percentile(array, [25, 50, 75], axis=0)  
row_percentiles = np.percentile(array, [25, 50, 75], axis=1)  


flat_mean = np.mean(array)
flat_median = np.median(array)
flat_std = np.std(array)

col_mean = np.mean(array, axis=0)
col_median = np.median(array, axis=0)
col_std = np.std(array, axis=0)

row_mean = np.mean(array, axis=1)
row_median = np.median(array, axis=1)
row_std = np.std(array, axis=1)


print("Element-wise Absolute Value:\n", abs_array, "\n")

print(f"Flattened Array Percentiles (25th, 50th, 75th):\n{flat_percentiles}\n")
print(f"Column-wise Percentiles:\n{col_percentiles}\n")
print(f"Row-wise Percentiles:\n{row_percentiles}\n")

print(f"Flattened Array: Mean={flat_mean}, Median={flat_median}, Std Dev={flat_std}\n")
print(f"Column-wise: Mean={col_mean}, Median={col_median}, Std Dev={col_std}\n")
print(f"Row-wise: Mean={row_mean}, Median={row_median}, Std Dev={row_std}")
# Out:
# Element-wise Absolute Value:
#  [[1 2 3]
#  [4 5 6]]
#
# Flattened Array Percentiles (25th, 50th, 75th):
# [-3.5 -0.5  2.5]
#
# Column-wise Percentiles:
# [[-2.75 -0.25 -3.75]
#  [-1.5   1.5  -1.5 ]
#  [-0.25  3.25  0.75]]
#
# Row-wise Percentiles:
# [[-0.5 -5. ]
#  [ 1.  -4. ]
#  [ 2.   0.5]]
#
# Flattened Array: Mean=-0.5, Median=-0.5, Std Dev=3.8622100754188224
#
# Column-wise: Mean=[-1.5  1.5 -1.5], Median=[-1.5  1.5 -1.5], Std Dev=[2.5 3.5 4.5]
#
# Row-wise: Mean=[ 0.66666667 -1.66666667], Median=[ 1. -4.], Std Dev=[2.05480467 4.78423336]

# %% [markdown]
# <b>Questionn 3</b> For the array: a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0]).<br>
# Find floor, ceiling and truncat

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])

print("Floor Values:", np.floor(a))
print("Ceiling Values:", np.ceil(a))
print("Truncated Values:", np.trunc(a))
print("Rounded Values:", np.round(a))
# Out:
# Floor Values: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling Values: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated Values: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded Values: [-2. -2. -0.  0.  2.  2.  3.]

# %% [markdown]
# <b> Question 4</b> WAP to swap two elements in a list in Python Using a Temporary Variable.

# %%
def swap(lst, index1, index2):
    temp = lst[index1]
    lst[index1] = lst[index2]
    lst[index2] = temp
    return lst

my_list = [1, 2, 3, 4, 5]
index1, index2 = 2, 3
print("Original List:", my_list)
print("Swapped List:", swap(my_list, index1, index2))
# Out:
# Original List: [1, 2, 3, 4, 5]
# Swapped List: [1, 2, 4, 3, 5]

# %% [markdown]
# <b>Question 5</b> Write a Python program to swap two elements in a set by converting it to a list first.

# %%
from collections import OrderedDict

def swap_elements_ordered_set(my_set, pos1, pos2):
    ordered_list = list(OrderedDict.fromkeys(my_set))
    if pos1 < 0 or pos2 < 0 or pos1 >= len(ordered_list) or pos2 >= len(ordered_list):
        print("Invalid positions!")
        return my_set
        
    ordered_list[pos1], ordered_list[pos2] = ordered_list[pos2], ordered_list[pos1]
    return OrderedDict.fromkeys(ordered_list)  

my_set = {10, 20, 30, 40, 50}  
pos1, pos2 = 1, 3 

print("Original set:", my_set)
swapped_set = swap_elements_ordered_set(my_set, pos1, pos2)
print("Ordered set after swapping:", set(swapped_set.keys()))
# Out:
# Original set: {50, 20, 40, 10, 30}
# Ordered set after swapping: {40, 10, 50, 20, 30}
